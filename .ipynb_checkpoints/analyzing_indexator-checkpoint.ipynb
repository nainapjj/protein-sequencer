# %%
# %matplotlib inline
import analyzePdbVolumes as an
import matplotlib.pyplot as plt

# %%
print "Analyzing 1DF4"
data_1DF4 = an.volumeErrorsForMotifs("pdbs/1DF4.pdb")

print "Analyzing 1P9I"
data_1P9I = an.volumeErrorsForMotifs("pdbs/1P9I.pdb")

print "Analyzing 2RJV"
data_2RJV = an.volumeErrorsForMotifs("pdbs/2RJV.pdb")

print "Analyzing 2RJY"
data_2RJY = an.volumeErrorsForMotifs("pdbs/2RJY.pdb")
# Out:
# Analyzing 1DF4
# Finding all possible motifs within the protein...
# Matching each motif with its corresponding un-normalized volume and std. deviation...
# Choosing the bottom portion of the motifs to perform least squares on...
# {'std': 2.35154208418, 'index': (3.0, 4.0, 26.0, 41.0), 'unVol': 69.37973001152601, 'amino': 'IVWW'}
# Number of motifs to perform least squares on: 121
# Analyzing 1P9I
# Finding all possible motifs within the protein...
# Matching each motif with its corresponding un-normalized volume and std. deviation...
# Choosing the bottom portion of the motifs to perform least squares on...
# {'std': 2.85616312734, 'index': (4.0, 7.0, 22.0, 29.0), 'unVol': 78.50166579196505, 'amino': 'LLVV'}
# Number of motifs to perform least squares on: 59
# Analyzing 2RJV
# Finding all possible motifs within the protein...
# Matching each motif with its corresponding un-normalized volume and std. deviation...
# ...

# %%
print "Looking at 1DF4"

plt.hist(data_1DF4["deltas"], 50)
plt.xlabel("Actual Volume - Predicted Volume")
plt.show()

plt.scatter(data_1DF4["deltas"], data_1DF4["stds"])
plt.xlabel("Delta Volume")
plt.ylabel("Std")
plt.show()
# Out:
# Looking at 1DF4

# %%
print "Looking at 1P9I"

plt.hist(data_1P9I["deltas"], 50)
plt.xlabel("Actual Volume - Predicted Volume")
plt.show()

plt.scatter(data_1P9I["deltas"], data_1P9I["stds"])
plt.xlabel("Delta Volume")
plt.ylabel("Std")
plt.show()
# Out:
# Looking at 1P9I

# %%
print "Looking at 2RJV"

plt.hist(data_2RJV["deltas"], 50)
plt.xlabel("Actual Volume - Predicted Volume")
plt.show()

plt.scatter(data_2RJV["deltas"], data_2RJV["stds"])
plt.xlabel("Delta Volume")
plt.ylabel("Std")
plt.show()
# Out:
# Looking at 2RJV

# %%
print "Looking at 2RJY"

plt.hist(data_2RJY["deltas"], 50)
plt.xlabel("Actual Volume - Predicted Volume")
plt.show()

plt.scatter(data_2RJY["deltas"], data_2RJY["stds"])
plt.xlabel("Delta Volume")
plt.ylabel("Std")
plt.show()
# Out:
# Looking at 2RJY
